# %%
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from config import *

# %%
import pandas as pd
from sales_predictor import extract_from_dataset
from preprocessing import missing_data_processing, data_preprocessing


data=pd.read_excel('SP_Train.xlsx')
data=missing_data_processing(data)

X,y=extract_from_dataset(data, 'Item_Outlet_Sales', ['Item_Identifier'])

X,y=data_preprocessing(X,y)

# %%
params={'n_estimators':range(2,200),'max_depth':range(1,1000), 'min_samples_leaf':range(1,1000), 'min_samples_split':[2,5,10]}
test_model=RandomForestRegressor()

# %%
params={'n_estimators':range(2,200)}
test_model=AdaBoostRegressor()

# %%
params={'n_neighbors':range(2,500),'metric':['euclidean', 'manhattan', 'minkowski']}
test_model=KNeighborsRegressor()

# %%
import numpy as np

params={'max_depth':range(1,1000), 'min_samples_leaf':range(1,1000), 'min_samples_split':[2,5,10],'ccp_alpha':np.linspace(0.00001, 10, 100)}
test_model=DecisionTreeRegressor()

# %%
r=RandomizedSearchCV(test_model, params, n_iter=30)
r.fit(X,y)
# Out:
# RandomizedSearchCV(estimator=DecisionTreeRegressor(), n_iter=30,
#                    param_distributions={'ccp_alpha': array([1.00000e-05, 1.01020e-01, 2.02030e-01, 3.03040e-01, 4.04050e-01,
#        5.05060e-01, 6.06070e-01, 7.07080e-01, 8.08090e-01, 9.09100e-01,
#        1.01011e+00, 1.11112e+00, 1.21213e+00, 1.31314e+00, 1.41415e+00,
#        1.51516e+00, 1.61617e+00, 1.71718e+00, 1.81819e+00, 1.91920e+00,
#        2.02021...
#        7.57576e+00, 7.67677e+00, 7.77778e+00, 7.87879e+00, 7.97980e+00,
#        8.08081e+00, 8.18182e+00, 8.28283e+00, 8.38384e+00, 8.48485e+00,
#        8.58586e+00, 8.68687e+00, 8.78788e+00, 8.88889e+00, 8.98990e+00,
#        9.09091e+00, 9.19192e+00, 9.29293e+00, 9.39394e+00, 9.49495e+00,
#        9.59596e+00, 9.69697e+00, 9.79798e+00, 9.89899e+00, 1.00000e+01]),
#                                         'max_depth': range(1, 1000),
#                                         'min_samples_leaf': range(1, 1000),
# ...

# %%
param_grid={'n_estimators':[5,10,20,50,100,150,200],
            'max_depth':[5,10,50,100,150,200], 
            'min_samples_leaf':[1,10,50,100,1000], 
            'min_samples_split':[2,3,5]}
g=GridSearchCV(model,param_grid=param_grid, cv=5, verbose=2)
g.fit(X,y)
# Out:
# Fitting 5 folds for each of 630 candidates, totalling 3150 fits
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=5; total time=   0.0s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=5; total time=   0.0s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=5; total time=   0.0s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=5; total time=   0.0s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=5; total time=   0.0s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=10; total time=   0.0s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=10; total time=   0.0s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=10; total time=   0.0s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=10; total time=   0.0s
# ...

# %%
pd.DataFrame(g.)
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.035630      0.003929         0.002205        0.000399
# 1         0.063021      0.000844         0.002316        0.000540
# 2         0.124143      0.001124         0.003048        0.000283
# 3         0.308218      0.002760         0.005209        0.000447
# 4         0.616461      0.003609         0.008512        0.000315
# ..             ...           ...              ...             ...
# 625       0.043348      0.003365         0.002717        0.000457
# 626       0.106920      0.004190         0.003630        0.000684
# 627       0.204817      0.011135         0.006597        0.001644
# 628       0.299379      0.007700         0.010490        0.002688
# 629       0.401478      0.013469         0.008952        0.000241
#
#      param_max_depth  param_min_samples_leaf  param_min_samples_split  \
# 0                  5                       1                        2
# ...
